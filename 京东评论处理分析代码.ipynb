# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import numpy

# %% [markdown]
# ### 读取商品评论  df_comments为最初DataFrame

# %%
# 读取包含好评、差评的Excel文件
df_comments = pd.read_excel('C:\\Users\\asus\\Desktop\\已处理好的数据\\IQOO-自营.xlsx')

# %%
df_test = DataFrame(df_comments,columns=['评价星级','评价内容'])
df_test_new = df_test.drop_duplicates() # 去掉重复的数据,5-18更新:通过Excel已经去重


# 取出好评、差评
active_com = df_test_new[df_test_new['评价星级']=='star5']
negative_com = df_test_new[df_test_new['评价星级']=='star1']

# %% [markdown]
# ### 将Series转为Str (用于后面的分词以及TF-IDF)

# %%
df_comments_str_active = "".join(i for i in active_com['评价内容'][:])
df_comments_str_negative = "".join(i for i in negative_com['评价内容'][:])

# %% [markdown]
# ### 利用jieba分词 && 去除停用词

# %%
import jieba

# 加载停用词
stopwords=pd.read_csv('D:\\Python\\Python-NLP\\tangyudi\\stopwords.txt',index_col=False,sep="\t",quoting=3,names=['stopword'], encoding='utf-8')
stopwords2=pd.read_csv('D:\\Python\\Python-NLP\\tangyudi\\stopwords2.txt',index_col=False,sep="\t",quoting=3,names=['stopword'], encoding='utf-8')

def drop_stopwords(contents,stopwords):
    contents_clean = []
    for line in contents:
        line_clean = []
        if line in stopwords:
                continue
        line_clean.append(line)
        contents_clean.append(line_clean)
    return contents_clean

        
# 更改分词器,采用自己的自定义词典,并通过notepad++改变txt文件编码
jieba.load_userdict("D:\\Python\\Python-NLP\\tangyudi\\userdict_CSDN_all.txt")
active_cut_contents = jieba.lcut(df_comments_str_active) #利用jieba分词  https://github.com/fxsjy/jieba
negative_cut_contents = jieba.lcut(df_comments_str_negative)
# contents = df_comments['评价内容'][:20].values.tolist() #评论转为list

stopwords = stopwords.stopword.values.tolist()
stopwords2 = stopwords2.stopword.values.tolist()


# 调用drop_stopwords() 去除停用词
active_contents_clean = drop_stopwords(active_cut_contents,stopwords)
negative_contents_clean = drop_stopwords(negative_cut_contents,stopwords2)


# 加一步清除 contents_clean_test 中的空格,contents_clean_test = [['超级'],['棒'],[' '],['体验'],['超乎'],[' ']]
def clean_none(list):
    for i in list:
        for j in i:
            if ' ' in i:
                i.remove(' ')

    list1 = []
    for i in list:
        if i:
            list1.append(i)
    return list1


# 得到去除空格的,格式为list of list :  [['超级'],['棒'],['体验'],['超乎']]
active_contents_clean = clean_none(active_contents_clean)
negative_contents_clean = clean_none(negative_contents_clean)


# 得到 ['超级','棒','体验','超乎','想象']
active_contents_clean_new = [str(x[0]) for x in active_contents_clean]
negative_contents_clean_new = [str(x[0]) for x in negative_contents_clean]


#  将['超级','棒','体验','超乎','想象'] 转为 DataFrame , 分为 积极 和 消极
df_all_words_active = DataFrame({'all_words':active_contents_clean_new})
# df_all_words.head(20)
df_all_words_negative = DataFrame({'all_words':negative_contents_clean_new})
# df_all_words_negative.head(10)
active_contents_clean
# df_all_words_active
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\asus\AppData\Local\Temp\jieba.cache
# Loading model cost 0.959 seconds.
# Prefix dict has been built succesfully.
# [['iQOO'],
#  ['非凡'],
#  ['电竞'],
#  ['体验'],
#  ['爽'],
#  ['充电'],
#  ['超快'],
#  ['电量'],
#  ['续航能力'],
#  ['超强'],
#  ['日常'],
#  ['需求'],
#  ['玩游'],
#  ['流畅'],
#  ['电竞'],
#  ['效果'],
#  ['很棒'],
#  ['机身'],
#  ['炫酷'],
#  ['手感'],
#  ['发热'],
#  ['通话质量'],
#  ['外观'],
#  ['熔岩'],
#  ['橙色'],
#  ['够'],
#  ['骚气'],
#  ['辨识'],
#  ['度高'],
#  ['漂亮'],
#  ['性能'],
#  ['骁龙'],
#  ['855'],
#  ['cpu'],
#  ['配合'],
#  ['128'],
#  ['内存'],
#  ['加'],
#  ['存储'],
#  ['足以'],
#  ['应对'],
#  ['需求'],
#  ['相机'],
#  ['数据'],
#  ['友商'],
#  ['亮眼'],
#  ['足够'],
#  ['兰机'],
#  ['主打'],
#  ['相机'],
#  ['音乐'],
#  ['续航'],
#  ['4000'],
#  ['毫安'],
#  ['电池'],
#  ['配合'],
#  ['瓦'],
#  ['快充'],
#  ['分钟'],
#  ['充满'],
#  ['秒杀'],
#  ['市面'],
#  ['特色'],
#  ['后置'],
#  ['炫'],
#  ['彩灯'],
#  ['独有'],
#  ['游戏'],
#  ['空间'],
#  ['游戏迷'],
#  ['太好了'],
#  ['4000'],
#  ['毫安'],
#  ['电池'],
#  ['续航'],
#  ['强大'],
#  ['流畅'],
#  ['眼睛'],
#  ['疲劳'],
#  ['屏幕'],
#  ['护眼'],
#  ['我用'],
#  ['好几年'],
#  ['充电'],
#  ['速度慢'],
#  ['死'],
#  ['两个'],
#  ['小时'],
#  ['充满'],
#  ['指纹解锁'],
#  ['整体'],
#  ['灯'],
#  ['很炫酷'],
#  ['利器'],
#  ['256'],
#  ['配置'],
#  ['牛'],
#  ['5g'],
#  ['上市'],
#  ['不用'],
#  ['换'],
#  ['性能'],
#  ['没得说'],
#  ['外观'],
#  ['漂亮'],
#  ['手感'],
#  ['特'],
#  ['指纹解锁'],
#  ['面部'],
#  ['解锁'],
#  ['灵敏'],
#  ['信号'],
#  ['乡下'],
#  ['信号'],
#  ['满格'],
#  ['唯一'],
#  ['耳机'],
#  ['到手'],
#  ['体验'],
#  ['不码'],
#  ['吃鸡'],
#  ['IQOO'],
#  ['非凡'],
#  ['电竞'],
#  ['体验'],
#  ['爽'],
#  ['第二个'],
#  ['电光'],
#  ['蓝'],
#  ['看重'],
#  ['性能'],
#  ['配置'],
#  ['王者'],
#  ['荣耀'],
#  ['刺激'],
#  ['战场'],
#  ['崩坏'],
#  ['压力'],
#  ['画质'],
#  ['全是'],
#  ['卡顿'],
#  ['帧'],
#  ['率'],
#  ['稳定'],
#  ['散热'],
#  ['44w'],
#  ['充电'],
#  ['超级'],
#  ['独立'],
#  ['3.5'],
#  ['耳机'],
#  ['OLED'],
#  ['屏幕'],
#  ['支持'],
#  ['屏下'],
#  ['指纹识别'],
#  ['nfc'],
#  ['坐车'],
#  ['刷'],
#  ['拍照'],
#  ['后置'],
#  ['三摄'],
#  ['够用'],
#  ['来个'],
#  ['12g'],
#  ['期待'],
#  ['更好'],
#  ['游戏'],
#  ['体验'],
#  ['骁龙'],
#  ['85544W'],
#  ['充电'],
#  ['游戏'],
#  ['按键'],
#  ['游戏'],
#  ['模式'],
#  ['智慧'],
#  ['人工'],
#  ['帮'],
#  ['发红包'],
#  ['颜色'],
#  ['好看'],
#  ['摄像头'],
#  ['音质'],
#  ['优化'],
#  ['下用'],
#  ['SQ'],
#  ['大赞'],
#  ['像素'],
#  ['足够'],
#  ['米酒'],
#  ['耍猴'],
#  ['顶级'],
#  ['处理器'],
#  ['发挥'],
#  ['应有'],
#  ['性能'],
#  ['性价比'],
#  ['高'],
#  ['快充'],
#  ['眼睛'],
#  ['看着'],
#  ['手感'],
#  ['两侧'],
#  ['腰线'],
#  ['变窄'],
#  ['单手'],
#  ['握持'],
#  ['指纹'],
#  ['刷脸'],
#  ['解锁'],
#  ['飞起'],
#  ['手'],
#  ['脱皮'],
#  ['本来'],
#  ['指纹识别'],
#  ['没报'],
#  ['希望'],
#  ['没想到'],
#  ['IQoo'],
#  ['秒解'],
#  ['666'],
#  ['安装'],
#  ['软件'],
#  ['WIFI'],
#  ['6S'],
#  ['发货'],
#  ['抢购'],
#  ['完'],
#  ['当天'],
#  ['发货'],
#  ['速度'],
#  ['点个'],
#  ['赞'],
#  ['打开'],
#  ['包装'],
#  ['确实'],
#  ['惊艳'],
#  ['手感'],
#  ['外观'],
#  ['十几个'],
#  ['APP'],
#  ['不到'],
#  ['三十秒'],
#  ['安装'],
#  ['完毕'],
#  ['速度'],
#  ['杠杠'],
#  ['不愧'],
#  ['858'],
#  ['处理器'],
#  ['性价比'],
#  ['高'],
#  ['X27'],
#  ['耍猴'],
#  ['桌面'],
#  ['弄成'],
#  ['主题'],
#  ['一件'],
#  ['换机'],
#  ['完美'],
#  ['不到'],
#  ['两分钟'],
#  ['音质'],
#  ['确实'],
#  ['滴'],
#  ['X21'],
#  ['逊色'],
#  ['接受'],
#  ['拍照'],
#  ['一百多'],
#  ['度'],
#  ['广角镜头'],
#  ['支持'],
#  ['夜景'],
#  ['拍摄'],
#  ['像素'],
#  ['很棒'],
#  ['4800'],
#  ['万'],
#  ['差'],
#  ['44W'],
#  ['快充'],
#  ['游戏迷'],
#  ['适合'],
#  ['四十多分钟'],
#  ['充满'],
#  ['支持'],
#  ['人脸'],
#  ['解锁'],
#  ['HIFI'],
#  ['芯片'],
#  ['QOO'],
#  ['部手机'],
#  ['耳机'],
#  ['配置'],
#  ['版'],
#  ['两天'],
#  ['手感'],
#  ['科技'],
#  ['感'],
#  ['44W'],
#  ['快充'],
#  ['给力'],
#  ['五十分钟'],
#  ['充满'],
#  ['电'],
#  ['耳机'],
#  ['漫步者'],
#  ['很棒'],
#  ['手机壳'],
#  ['nice'],
#  ['短暂'],
#  ['手'],
#  ['体验'],
#  ['价格'],
#  ['真香'],
#  ['保留'],
#  ['3.5'],
#  ['耳机'],
#  ['孔'],
#  ['好评'],
#  ['代'],
#  ['指纹解锁'],
#  ['媲美'],
#  ['电容'],
#  ['指纹'],
#  ['亮点'],
#  ['莫过于'],
#  ['44w'],
#  ['快充'],
#  ['形状'],
#  ['胶囊'],
#  ['数据线'],
#  ['更好'],
#  ['边充'],
#  ['边玩'],
#  ['不想'],
#  ['用过'],
#  ['说好'],
#  ['再也'],
#  ['回不去'],
#  ['整体'],
#  ['做工'],
#  ['无可挑剔'],
#  ['大厂'],
#  ['品控'],
#  ['放心'],
#  ['6.41'],
#  ['英寸'],
#  ['1080'],
#  ['2340'],
#  ['像素'],
#  ['AMOLED'],
#  ['屏幕'],
#  ['整体素质'],
#  ['优秀'],
#  ['显示'],
#  ['效果'],
#  ['细腻'],
#  ['设置'],
#  ['中'],
#  ['自定义'],
#  ['屏幕'],
#  ['色温'],
#  ['水滴'],
#  ['很小'],
#  ['下巴'],
#  ['很窄'],
#  ['整体'],
#  ['全面屏'],
#  ['视觉效果'],
#  ['很赞'],
#  ['两个'],
#  ['压感'],
#  ['按键'],
#  ['位置'],
#  ['恰到好处'],
#  ['震动'],
#  ['反馈'],
#  ['优秀'],
#  ['总有'],
#  ['一瞬间'],
#  ['误认为'],
#  ['实体'],
#  ['按键'],
#  ['骁龙'],
#  ['855'],
#  ['发挥'],
#  ['比较稳定'],
#  ['超级'],
#  ['液冷'],
#  ['热管'],
#  ['导热'],
#  ['高效'],
#  ['降低'],
#  ['机身'],
#  ['温度'],
#  ['游戏'],
#  ['玩家'],
#  ['福音'],
#  ['索尼'],
#  ['IMX363'],
#  ['表现'],
#  ['失望'],
#  ['常规'],
#  ['光线'],
#  ['白平衡'],
#  ['控'],
#  ['准确'],
#  ['色彩'],
#  ['还原'],
#  ['真实'],
#  ['超级'],
#  ['夜景'],
#  ['模式'],
#  ['过暗'],
#  ['区域'],
#  ['噪点'],
#  ['整体'],
#  ['表现'],
#  ['协调'],
#  ['大片'],
#  ['既视感'],
#  ['三千'],
#  ['价位'],
#  ['段'],
#  ['中'],
#  ['优秀'],
#  ['安卓'],
#  ['优秀'],
#  ['做工'],
#  ['顶级'],
#  ['硬件'],
#  ['配置'],
#  ['近期'],
#  ['想换'],
#  ['选择'],
#  ['44w'],
#  ['快充'],
#  ['旗舰'],
#  ['中'],
#  ['闪耀'],
#  ['点'],
#  ['快递'],
#  ['小哥'],
#  ['速度'],
#  ['够快'],
#  ['价格'],
#  ['香'],
#  ['3.5'],
#  ['耳机'],
#  ['孔'],
#  ['好评'],
#  ['指纹解锁'],
#  ['媲美'],
#  ['电容'],
#  ['指纹'],
#  ['亮点'],
#  ['莫过于'],
#  ['44w'],
#  ['快充'],
#  ['形状'],
#  ['胶囊'],
#  ['数据线'],
#  ['更好'],
#  ['边充'],
#  ['边玩'],
#  ['不想'],
#  ['用过'],
#  ['说好'],
#  ['再也'],
#  ['回不去'],
#  ['整体'],
#  ['做工'],
#  ['无可挑剔'],
#  ['大厂'],
#  ['品控'],
#  ['放心'],
#  ['6.41'],
#  ['英寸'],
#  ['1080'],
#  ['2340'],
#  ['像素'],
#  ['AMOLED'],
#  ['屏幕'],
#  ['整体素质'],
#  ['优秀'],
#  ['显示'],
#  ['效果'],
#  ['细腻'],
#  ['设置'],
#  ['中'],
#  ['自定义'],
#  ['屏幕'],
#  ['色温'],
#  ['水滴'],
#  ['很小'],
#  ['下巴'],
#  ['很窄'],
#  ['整体'],
#  ['全面屏'],
#  ['视觉效果'],
#  ['很赞'],
#  ['两个'],
#  ['压感'],
#  ['按键'],
#  ['位置'],
#  ['恰到好处'],
#  ['震动'],
#  ['反馈'],
#  ['优秀'],
#  ['总有'],
#  ['一瞬间'],
#  ['误认为'],
#  ['实体'],
#  ['按键'],
#  ['骁龙'],
#  ['855'],
#  ['发挥'],
#  ['比较稳定'],
#  ['超级'],
#  ['液冷'],
#  ['热管'],
#  ['导热'],
#  ['高效'],
#  ['降低'],
#  ['机身'],
#  ['温度'],
#  ['游戏'],
#  ['玩家'],
#  ['福音'],
#  ['索尼'],
#  ['IMX363'],
#  ['表现'],
#  ['失望'],
#  ['常规'],
#  ['光线'],
#  ['白平衡'],
#  ['控'],
#  ['准确'],
#  ['色彩'],
#  ['还原'],
#  ['真实'],
#  ['超级'],
#  ['夜景'],
#  ['模式'],
#  ['过暗'],
#  ['区域'],
#  ['噪点'],
#  ['整体'],
#  ['表现'],
#  ['协调'],
#  ['大片'],
#  ['既视感'],
#  ['三千'],
#  ['价位'],
#  ['段'],
#  ['中'],
#  ['优秀'],
#  ['安卓'],
#  ['优秀'],
#  ['做工'],
#  ['顶级'],
#  ['硬件'],
#  ['配置'],
#  ['近期'],
#  ['想换'],
#  ['选择'],
#  ['44w'],
#  ['快充'],
#  ['旗舰'],
#  ['中'],
#  ['闪耀'],
#  ['点'],
#  ['第一次'],
#  ['充电'],
#  ['好快'],
#  ['几分钟'],
#  ['电池容量'],
#  ['好久'],
#  ['电'],
#  ['文件'],
#  ['玩游戏'],
#  ['体验'],
#  ['拍摄'],
#  ['比米'],
#  ['玩游戏'],
#  ['网'],
#  ['不卡'],
#  ['触感'],
#  ['指纹解锁'],
#  ['好快'],
#  ['指纹解锁'],
#  ['快递'],
#  ['小哥'],
#  ['速度'],
#  ['够快'],
#  ['点多'],
#  ['点'],
#  ['到货'],
#  ['赞'],
#  ['价格'],
#  ['香'],
#  ['3.5'],
#  ['耳机'],
#  ['孔'],
#  ['好评'],
#  ['指纹解锁'],
#  ['媲美'],
#  ['电容'],
#  ['指纹'],
#  ['亮点'],
#  ['莫过于'],
#  ['44w'],
#  ['快充'],
#  ['形状'],
#  ['胶囊'],
#  ['数据线'],
#  ['更好'],
#  ['边充'],
#  ['边玩'],
#  ['不想'],
#  ['用过'],
#  ['说好'],
#  ['再也'],
#  ['回不去'],
#  ['整体'],
#  ['做工'],
#  ['无可挑剔'],
#  ['大厂'],
#  ['品控'],
#  ['放心'],
#  ['6.41'],
#  ['英寸'],
#  ['1080'],
#  ['2340'],
#  ['像素'],
#  ['AMOLED'],
#  ['屏幕'],
#  ['整体素质'],
#  ['优秀'],
#  ['显示'],
#  ['效果'],
#  ['细腻'],
#  ['设置'],
#  ['中'],
#  ['自定义'],
#  ['屏幕'],
#  ['色温'],
#  ['水滴'],
#  ['很小'],
#  ['下巴'],
#  ['很窄'],
#  ['整体'],
#  ['全面屏'],
#  ['视觉效果'],
#  ['很赞'],
#  ['两个'],
#  ['压感'],
#  ['按键'],
#  ['位置'],
#  ['恰到好处'],
#  ['震动'],
#  ['反馈'],
#  ['优秀'],
#  ['总有'],
#  ['一瞬间'],
#  ['误认为'],
#  ['实体'],
#  ['按键'],
#  ['骁龙'],
#  ['855'],
#  ['发挥'],
#  ['比较稳定'],
#  ['超级'],
#  ['液冷'],
#  ['热管'],
#  ['导热'],
#  ['高效'],
#  ['降低'],
#  ['机身'],
#  ['温度'],
#  ['游戏'],
#  ['玩家'],
#  ['福音'],
#  ['索尼'],
#  ['IMX363'],
#  ['表现'],
#  ['失望'],
#  ['常规'],
#  ['光线'],
#  ['白平衡'],
#  ['控'],
#  ['准确'],
#  ['色彩'],
#  ['还原'],
#  ['真实'],
#  ['超级'],
#  ['夜景'],
#  ['模式'],
#  ['过暗'],
#  ['区域'],
#  ['噪点'],
#  ['整体'],
#  ['表现'],
#  ['协调'],
#  ['大片'],
#  ['既视感'],
#  ['三千'],
#  ['价位'],
#  ['段'],
#  ['中'],
#  ['优秀'],
#  ['安卓'],
#  ['优秀'],
#  ['做工'],
#  ['顶级'],
#  ['硬件'],
#  ['配置'],
#  ['近期'],
#  ['想换'],
#  ['选择'],
#  ['44w'],
#  ['快充'],
#  ['旗舰'],
#  ['中'],
#  ['闪耀'],
#  ['点'],
#  ['价格'],
#  ['真香'],
#  ['保留'],
#  ['3.5'],
#  ['耳机'],
#  ['孔'],
#  ['好评'],
#  ['代'],
#  ['指纹解锁'],
#  ['媲美'],
#  ['电容'],
#  ['指纹'],
#  ['亮点'],
#  ['莫过于'],
#  ['44w'],
#  ['快充'],
#  ['形状'],
#  ['胶囊'],
#  ['数据线'],
#  ['更好'],
#  ['边充'],
#  ['边玩'],
#  ['不想'],
#  ['用过'],
#  ['说好'],
#  ['再也'],
#  ['回不去'],
#  ['整体'],
#  ['做工'],
#  ['无可挑剔'],
#  ['大厂'],
#  ['品控'],
#  ['放心'],
#  ['6.41'],
#  ['英寸'],
#  ['1080'],
#  ['2340'],
#  ['像素'],
#  ['AMOLED'],
#  ['屏幕'],
#  ['整体素质'],
#  ['优秀'],
#  ['显示'],
#  ['效果'],
#  ['细腻'],
#  ['设置'],
#  ['中'],
#  ['自定义'],
#  ['屏幕'],
#  ['色温'],
#  ['水滴'],
#  ['很小'],
#  ['下巴'],
#  ['很窄'],
#  ['整体'],
#  ['全面屏'],
#  ['视觉效果'],
#  ['很赞'],
#  ['两个'],
#  ['压感'],
#  ['按键'],
#  ['位置'],
#  ['恰到好处'],
#  ['震动'],
#  ['反馈'],
#  ['优秀'],
#  ['总有'],
#  ['一瞬间'],
#  ['误认为'],
#  ['实体'],
#  ['按键'],
#  ['骁龙'],
#  ['855'],
#  ['发挥'],
#  ['比较稳定'],
#  ['超级'],
#  ['液冷'],
#  ['热管'],
#  ['导热'],
#  ['高效'],
#  ['降低'],
#  ['机身'],
#  ['温度'],
#  ['游戏'],
#  ['玩家'],
#  ['福音'],
#  ['索尼'],
#  ['IMX363'],
#  ['表现'],
#  ['失望'],
#  ['常规'],
#  ['光线'],
#  ['白平衡'],
#  ['控'],
#  ['准确'],
#  ['色彩'],
#  ['还原'],
#  ['真实'],
#  ['超级'],
#  ['夜景'],
#  ['模式'],
#  ['过暗'],
#  ['区域'],
#  ['噪点'],
#  ['整体'],
#  ['表现'],
#  ['协调'],
#  ['大片'],
#  ['既视感'],
#  ['三千'],
#  ['价位'],
#  ['段'],
#  ['中'],
#  ['优秀'],
#  ['安卓'],
#  ['优秀'],
#  ['做工'],
#  ['顶级'],
#  ['硬件'],
#  ['配置'],
#  ['近期'],
#  ['想换'],
#  ['选择'],
#  ['44w'],
#  ['快充'],
#  ['旗舰'],
#  ['中'],
#  ['闪耀'],
#  ['点'],
#  ['屏幕'],
#  ['效果'],
#  ['王者'],
#  ['荣耀'],
#  ['速度'],
#  ['没法'],
#  ['更好'],
#  ['虚拟'],
#  ['键'],
#  ['反馈'],
#  ['舒服'],
#  ['整机'],
#  ['造型'],
#  ['游戏'],
#  ['浮夸'],
#  ['顶级'],
#  ['配置'],
#  ['冷酷'],
#  ['造型'],
#  ['iQOO'],
#  ['收到'],
#  ['这电'],
#  ['竞级'],
#  ['游戏'],
#  ['体验'],
#  ['太爽了'],
#  ['屏幕'],
#  ['指纹'],
#  ['贼'],
#  ['充电'],
#  ['极快'],
#  ['游戏'],
#  ['画质'],
#  ['爽'],
#  ['iQOO'],
#  ['真是太'],
#  ['赞'],
#  ['12g'],
#  ['运存'],
#  ['128'],
#  ['储存'],
#  ['够'],
#  ['好几年'],
#  ['电'],
#  ['竞级'],
#  ['非凡'],
#  ['体验'],
#  ['款'],
#  ['关注'],
#  ['好久'],
#  ['官博'],
#  ['预告'],
#  ['发布会'],
#  ['价格'],
#  ['开心'],
#  ['真香机'],
#  ['无疑'],
#  ['傻子'],
#  ['足够'],
#  ['良心'],
#  ['发布会'],
#  ['完后'],
#  ['全款'],
#  ['预定'],
#  ['钱花'],
#  ['爽'],
#  ['等待'],
#  ['难熬'],
#  ['天才'],
#  ['发货'],
#  ['终于'],
#  ['收到'],
#  ['好开心'],
#  ['好开心'],
#  ['重度'],
#  ['患者'],
#  ['续航'],
#  ['很高'],
#  ['烦死'],
#  ['频繁'],
#  ['充电'],
#  ['iQOO'],
#  ['电池'],
#  ['下定决心'],
#  ['更何况'],
#  ['配置'],
#  ['高'],
#  ['超级'],
#  ['闪充'],
#  ['44W'],
#  ['真'],
#  ['随便说说'],
#  ['这是'],
#  ['神仙'],
#  ['充电'],
#  ['速度'],
#  ['眼看'],
#  ['电量'],
#  ['往上升'],
#  ['开心'],
#  ['爆'],
#  ['打游戏'],
#  ['一局'],
#  ['吃鸡'],
#  ['骁龙'],
#  ['855'],
#  ['性能'],
#  ['彪悍'],
#  ['跳伞'],
#  ['落地'],
#  ['多人开'],
#  ['开车'],
#  ['卡'],
#  ['情况'],
#  ['动作'],
#  ['一气呵成'],
#  ['流畅'],
#  ['画质'],
#  ['开'],
#  ['超级'],
#  ['细腻'],
#  ['流畅'],
#  ['不掉'],
#  ['帧'],
#  ['用过'],
#  ['安卓'],
#  ['机都'],
#  ['游戏'],
#  ['优化'],
#  ['人性化'],
#  ['隐藏式'],
#  ['压感'],
#  ['按键'],
#  ['四指'],
#  ['联动'],
#  ['操作'],
#  ['花式'],
#  ['秀'],
#  ['操作'],
#  ['关键时刻'],
#  ['到了'],
#  ['外挂'],
#  ...]

# %% [markdown]
# ###  加载用户字典 && 基于 TF-IDF 算法的关键词抽取(另TextRank)

# %%
import jieba.analyse
#  extract_tags() 传入一个list
jieba.analyse.set_stop_words("D:\\Python\\Python-NLP\\tangyudi\\stopwords.txt")
tags_TF_IDF = jieba.analyse.extract_tags(df_comments_str_active, withWeight =False,topK=8)

tags_TextRank = jieba.analyse.textrank(df_comments_str_active, topK=8, withWeight=True)
#  df_comments_str_active
tags_TF_IDF,tags_TextRank
# Out:
# (['充电', '855', '游戏', '流畅', '吃鸡', '快充', '拍照', '玩游戏'],
#  [('充电', 1.0),
#   ('游戏', 0.8607247014505186),
#   ('速度', 0.7555496223510816),
#   ('拍照', 0.46874727314861575),
#   ('屏幕', 0.46577129159118524),
#   ('吃鸡', 0.45729860210380635),
#   ('电池', 0.41671070308455643),
#   ('玩游戏', 0.3958192765970956)])

# %% [markdown]
# ### 统计词频

# %%
words_count_active=df_all_words_active.groupby(by=['all_words'])['all_words'].agg({"count":numpy.size})
words_count_active=words_count_active.reset_index().sort_values(by=["count"],ascending=False)

words_count_neg=df_all_words_negative.groupby(by=['all_words'])['all_words'].agg({"count":numpy.size})
words_count_neg=words_count_neg.reset_index().sort_values(by=["count"],ascending=False)

# %% [markdown]
# ### 绘制词云

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, WordCloud
from pyecharts.globals import SymbolType

word_frequence_active = [(x[0],x[1]) for x in words_count_active.head(800).values] # 生成词云所需要的格式 [('充电', 83), ('流畅', 53), ('玩游戏', 49)]

word_neg_frequence = [(x[0],x[1]) for x in words_count_neg.head(800).values]

def wordcloud_base(word_frequence) -> WordCloud:
    c = (
        WordCloud()
        .add("", word_frequence, word_size_range=[20, 100])
        .set_global_opts(title_opts=opts.TitleOpts(title="WordCloud"))
    )
    return c

# 正向评价词云
wordcloud_base(word_frequence_active).render_notebook()  
#  负向评价词云
wordcloud_base(word_neg_frequence).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#     <div id="3e32f24985fd432d8b580cbebb15dfcc" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'echarts-wordcloud'], function(echarts) {
#         var chart_3e32f24985fd432d8b580cbebb15dfcc = echarts.init(
#             document.getElementById('3e32f24985fd432d8b580cbebb15dfcc'), 'white', {renderer: 'canvas'});
#         var option_3e32f24985fd432d8b580cbebb15dfcc = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u8033\u673a",
#                     "value": 250,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(120,2,156)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5ba2\u670d",
#                     "value": 148,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(11,47,69)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5dee\u8bc4",
#                     "value": 131,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(104,37,23)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u738b\u8005",
#                     "value": 116,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(26,137,39)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4eac\u4e1c",
#                     "value": 105,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(92,91,20)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5145\u7535",
#                     "value": 103,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(81,93,28)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5783\u573e",
#                     "value": 93,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(1,142,77)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u611f\u89c9",
#                     "value": 89,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(94,40,79)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5361",
#                     "value": 81,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(101,108,139)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0d\u597d",
#                     "value": 74,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(1,119,90)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5c4f\u5e55",
#                     "value": 71,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(44,88,146)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5dee",
#                     "value": 70,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(101,28,39)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4fe1\u53f7",
#                     "value": 66,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(76,129,159)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u73a9\u6e38\u620f",
#                     "value": 62,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(27,71,73)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8363\u8000",
#                     "value": 62,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(74,36,142)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u60f3",
#                     "value": 57,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(49,137,124)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f53\u9a8c",
#                     "value": 57,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(72,0,32)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e00\u661f",
#                     "value": 55,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(35,105,34)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7535\u6c60",
#                     "value": 54,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(29,44,24)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e00\u70b9",
#                     "value": 53,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(24,94,57)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7f51\u7edc",
#                     "value": 53,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(111,105,45)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5403\u9e21",
#                     "value": 53,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(44,37,94)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7cfb\u7edf",
#                     "value": 52,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(22,8,142)"
#                         }

# %% [markdown]
# ### 绘制正面负面评价分布图

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar


'''
获取好评中各个属性数 : 价格 外观 续航 屏幕 内存 系统 解锁 游戏
'''
def get_property_nums(words_count):
    price_num = appearance_num= words_count[words_count['all_words'].str.contains('价格|贵|便宜|性价比高')].apply(np.sum)['count']
    photo = words_count[words_count['all_words'].str.contains('拍照|摄像|照相')].apply(np.sum)['count']
    appearance_num= words_count[words_count['all_words'].str.contains('外观|外形')].apply(np.sum)['count']
    battery_num = words_count[words_count['all_words'].str.contains('续航|电池|充电')].apply(np.sum)['count'] #得到int
    scree_num = words_count[words_count['all_words'].str.contains('屏幕')].apply(np.sum)['count']
    unlock = words_count[words_count['all_words'].str.contains('解锁|锁屏|指纹')].apply(np.sum)['count']
    game = words_count[words_count['all_words'].str.contains('游戏|电竞|王者|王者荣耀|吃鸡|刺激战场')].apply(np.sum)['count']
    system = words_count[words_count['all_words'].str.contains('系统|内存|流畅|配置|855')].apply(np.sum)['count']
    return price_num,photo,appearance_num,battery_num,scree_num,unlock,game,system



'''
add_xaxis()传入一个列表,作为横坐标
add_yaxis()传入一个列表,作为柱形图y数值
'''
def bar_stack0() -> Bar:
    properties = ['价格','拍照','外观','电池','屏幕','解锁','游戏','系统']
    c = (
        Bar()
        .add_xaxis(properties)
        .add_yaxis("好评",list(get_property_nums(words_count_active)), stack="stack1")
        .add_yaxis("差评", list(get_property_nums(words_count_neg)), stack="stack1")
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(title_opts=opts.TitleOpts(title="手机属性口碑分布图"))
    )
    return c

bar_stack0().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="338bbbfb0e4646959a127ab51fe3d6ee" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_338bbbfb0e4646959a127ab51fe3d6ee = echarts.init(
#             document.getElementById('338bbbfb0e4646959a127ab51fe3d6ee'), 'white', {renderer: 'canvas'});
#         var option_338bbbfb0e4646959a127ab51fe3d6ee = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u597d\u8bc4",
#             "data": [
#                 51,
#                 260,
#                 157,
#                 768,
#                 176,
#                 240,
#                 845,
#                 710
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "fontSize": 12
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5dee\u8bc4",
#             "data": [
#                 23,
#                 59,
#                 17,
#                 186,
#                 72,
#                 87,
#                 287,
#                 119
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "fontSize": 12
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u597d\u8bc4",
#                 "\u5dee\u8bc4"
#             ],
#             "selected": {
#                 "\u597d\u8bc4": true,
#                 "\u5dee\u8bc4": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4ef7\u683c",
#                 "\u62cd\u7167",
#                 "\u5916\u89c2",
#                 "\u7535\u6c60",
#                 "\u5c4f\u5e55",
#                 "\u89e3\u9501",
#                 "\u6e38\u620f",
#                 "\u7cfb\u7edf"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u624b\u673a\u5c5e\u6027\u53e3\u7891\u5206\u5e03\u56fe"
#         }
#     ]
# };
#         chart_338bbbfb0e4646959a127ab51fe3d6ee.setOption(option_338bbbfb0e4646959a127ab51fe3d6ee);
#     });
# </script>

# %% [markdown]
# ### 绘制容量颜色销量

# %%
# 获取颜色
df_color = DataFrame(df_comments,columns=['颜色'])
# 去重参考 https://www.jb51.net/article/155577.htm
df_color_new = df_color.drop_duplicates()
df_color_new_group =df_color.groupby(by=['颜色'])['颜色'].agg({"count":numpy.size})
df_color_new_group = df_color_new_group.reset_index().sort_values(by=["count"],ascending=False)

color = [x for x in df_color_new_group['颜色'][:]] #填入颜色饼状图的名称列表
color_num = [float(str(x)) for x in df_color_new_group['count'][:]]


#  获取容量
df_volume = DataFrame(df_comments,columns=['容量'])
df_volume_new = df_volume.drop_duplicates()
df_volume_new_group =df_volume.groupby(by=['容量'])['容量'].agg({"count":numpy.size})
df_volume_new_group = df_volume_new_group.reset_index().sort_values(by=["count"],ascending=False)

volume = [x for x in df_volume_new_group['容量'][:]] #填入颜色饼状图的名称列表
volume_num = [float(str(x)) for x in df_volume_new_group['count'][:]]


volume,volume_num
str(color_num)
color,color_num
# Out:
# (['电光蓝', '熔岩橙', '武士黑'], [1481.0, 445.0, 69.0])

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, Pie


# 获取好评数,差评数,得到int
positive_num = df_test_new[df_test_new['评价星级']=='star5'].shape[0]
negative_num = df_test_new[df_test_new['评价星级']=='star1'].shape[0]


# 计算占比
positive_num_proportion = positive_num / (positive_num + negative_num)
negative_num_proportion = negative_num / (positive_num + negative_num)


def pie_color() -> Pie:
    c = (
        Pie()
        .add("", [list(z) for z in zip(color, color_num)])
        .set_global_opts(title_opts=opts.TitleOpts(title="各种颜色销量占比"))
        .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    )
    return c

def pie_volume() -> Pie:
    c = (
        Pie()
        .add("", [list(z) for z in zip(volume, volume_num)])
        .set_global_opts(title_opts=opts.TitleOpts(title="各种容量销量占比"))
        .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    )
    return c
# pie_volume().render_notebook()
pie_color().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="11178adbe1cc4e59af32a6e3d655cce2" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_11178adbe1cc4e59af32a6e3d655cce2 = echarts.init(
#             document.getElementById('11178adbe1cc4e59af32a6e3d655cce2'), 'white', {renderer: 'canvas'});
#         var option_11178adbe1cc4e59af32a6e3d655cce2 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u7535\u5149\u84dd",
#                     "value": 1481.0
#                 },
#                 {
#                     "name": "\u7194\u5ca9\u6a59",
#                     "value": 445.0
#                 },
#                 {
#                     "name": "\u6b66\u58eb\u9ed1",
#                     "value": 69.0
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "fontSize": 12,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7535\u5149\u84dd",
#                 "\u7194\u5ca9\u6a59",
#                 "\u6b66\u58eb\u9ed1"
#             ],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5404\u79cd\u989c\u8272\u9500\u91cf\u5360\u6bd4"
#         }
#     ]
# };
#         chart_11178adbe1cc4e59af32a6e3d655cce2.setOption(option_11178adbe1cc4e59af32a6e3d655cce2);
#     });
# </script>

# %%
pie_volume().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="38fdf3a3c61242df95b25bfea3dbdcb9" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_38fdf3a3c61242df95b25bfea3dbdcb9 = echarts.init(
#             document.getElementById('38fdf3a3c61242df95b25bfea3dbdcb9'), 'white', {renderer: 'canvas'});
#         var option_38fdf3a3c61242df95b25bfea3dbdcb9 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "8GB+128GB",
#                     "value": 1342.0
#                 },
#                 {
#                     "name": "6GB+128GB",
#                     "value": 366.0
#                 },
#                 {
#                     "name": "12GB+128GB",
#                     "value": 168.0
#                 },
#                 {
#                     "name": "12GB+256GB",
#                     "value": 103.0
#                 },
#                 {
#                     "name": "8GB+256GB",
#                     "value": 14.0
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "fontSize": 12,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "8GB+128GB",
#                 "6GB+128GB",
#                 "12GB+128GB",
#                 "12GB+256GB",
#                 "8GB+256GB"
#             ],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5404\u79cd\u5bb9\u91cf\u9500\u91cf\u5360\u6bd4"
#         }
#     ]
# };
#         chart_38fdf3a3c61242df95b25bfea3dbdcb9.setOption(option_38fdf3a3c61242df95b25bfea3dbdcb9);
#     });
# </script>

# %% [markdown]
# ### gensim LDA

# %%
from gensim import corpora, models, similarities
import gensim
from gensim.models import word2vec

# %%
#  参数texts就是若干个被拆成单词集合的文档的集合，而Dictionary就是把所有单词取一个set(),并对set中每个单词分配一个id号的map;  猜测是(1,'超级')
dictionary = corpora.Dictionary(active_contents_clean)
#  doc2bow把文档 doc变成一个稀疏向量，[(0, 1), (1, 1)]，表明id为0,1的词汇出现了1次，至于其他词汇，没有出现。
corpus = [dictionary.doc2bow(sentence) for sentence in active_contents_clean]
# corpus[:20]

lda = gensim.models.ldamodel.LdaModel(corpus=corpus, id2word=dictionary, num_topics=3)  # 自己指定主题

# %%
def get_LDA(contents_clean):
    dictionary = corpora.Dictionary(contents_clean)
    corpus = [dictionary.doc2bow(sentence) for sentence in contents_clean]
    lda = gensim.models.ldamodel.LdaModel(corpus=corpus, id2word=dictionary, num_topics=3)  # 自己指定主题
    topic = "<p>"+lda.print_topic(0, topn=5)+"</p>"+"<p>"+lda.print_topic(1, topn=5)+"</p>"+"<p>"+lda.print_topic(2, topn=5)+"</p>"
    return topic

lda_active = '<p>[正向评价LDA]</p>'+get_LDA(active_contents_clean)
lda_negative = '<p>[负向向评价LDA]</p>'+get_LDA(negative_contents_clean)

# %%
for topic in lda.print_topics(num_topics=5, num_words=5):
    print (topic[1])
# Out:
# 0.052*"充电" + 0.030*"流畅" + 0.027*"游戏" + 0.019*"像素" + 0.017*"电池"
# 0.026*"玩游戏" + 0.025*"体验" + 0.024*"超级" + 0.016*"拍照" + 0.015*"杠杠"
# 0.033*"性能" + 0.023*"手感" + 0.021*"外观" + 0.020*"855" + 0.020*"速度"

# %%
lda_active + '<br>' + lda_negative
# active_contents_clean
# Out:
# '<p>[正向评价LDA]</p><p>0.039*"性能" + 0.027*"手感" + 0.024*"855" + 0.022*"快充" + 0.014*"希望"</p><p>0.050*"充电" + 0.029*"流畅" + 0.026*"游戏" + 0.024*"吃鸡" + 0.024*"超级"</p><p>0.022*"玩游戏" + 0.022*"外观" + 0.022*"速度" + 0.022*"体验" + 0.015*"好用"</p><br><p>[负向向评价LDA]</p><p>0.023*"客服" + 0.016*"垃圾" + 0.015*"京东" + 0.012*"差" + 0.011*"想"</p><p>0.023*"王者" + 0.012*"玩游戏" + 0.012*"电池" + 0.012*"荣耀" + 0.011*"吃鸡"</p><p>0.055*"耳机" + 0.027*"充电" + 0.021*"差评" + 0.018*"感觉" + 0.015*"屏幕"</p>'

# %% [markdown]
# ### 将分析结果写入elasticsearch

# %%
from elasticsearch import Elasticsearch

client = Elasticsearch(hosts=["127.0.0.1"])

title = df_comments.loc[0,'页面标题']
url = df_comments.loc[0,'页面网址']
star=df_comments.loc[0,'评价星级']
content = lda_active + '<br>' + lda_negative

wordcloud_positive = str(word_frequence_active)
wordcloud_negative = str(word_neg_frequence)
# proportion_positive = str(float('%.2f' % positive_num_proportion))
# proportion_negative =  str(float('%.2f' % negative_num_proportion))
koubei_positive = str(list(get_property_nums(words_count_active)))
koubei_negative = str(list(get_property_nums(words_count_neg)))

doc_index ="jingdong"
doc_type = "comment"
doc_body = {
    "title":title,
    "create_date": "2019-06-01",
    "content": content,
    "url": url,
    "tags": str(tags_TF_IDF),
    "star": "star5",
    "wordcloud_positive":wordcloud_positive,
    "wordcloud_negative":wordcloud_negative,
    "color":str(color),
    "color_num1":str(color_num),
    "volume":str(volume),
    "volume_num1":str(volume_num),
    "koubei_positive":koubei_positive,
    "koubei_negative":koubei_negative
}
try:
    # client.bulk(index=doc_index, doc_type=doc_type, body=doc_body)
    client.index(index=doc_index,doc_type=doc_type,body = doc_body,id=1)
    print("success")
except Exception as e:
    print(e)
# Out:
# success
